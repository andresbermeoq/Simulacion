# %% [markdown]
# # Universidad Politecnica Salesiana
#
# ### Nombre: Andres Bermeo
# #### Fecha: 25/Octubre/2021

# %% [markdown]
# ### Simulacion de movimientos de vehiculos entre la carrera de la provincia de los Rios entre Laurel y Junquillal

# %% [markdown]
# ![Screen%20Shot%202021-10-27%20at%2015.00.32.png](attachment:Screen%20Shot%202021-10-27%20at%2015.00.32.png)

# %% [markdown]
# ![Screen%20Shot%202021-10-27%20at%2015.22.20.png](attachment:Screen%20Shot%202021-10-27%20at%2015.22.20.png)

# %% [markdown]
# Fuente de Datos : https://www.compraspublicas.gob.ec/ProcesoContratacion/compras/PC/bajarArchivo.cpe?Archivo=i711XlTWIwqoOYsf6EnU61NaHJTl-SMCvUVvZfXaCKU
